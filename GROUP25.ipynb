# %% [markdown]
# # GROUP 25
#
# #### MANOJ SANJAY LONDHE - 6672282
# #### HITESH SAI MARISETTY - 6673633
# #### MALLAVARAPU ARUN  - 6679047

# %% [markdown]
# # Consumer Complaints Classification

# %% [markdown]
# ## Group Deployment

# %% [markdown]
# #### 1 - Model Serving Options:
# ##### Installing a machine learning model into the production is nothing but making the model available to the system.Several ways are there to serve a machine leraning model.We as a group will explain different ways of deploying a ML model.
#
# ##### Tensorflow Serving: TensorFlow Serving is considered as one of the most efficient and top performing serving system for ML models.It is designed for production environment. With tensorFlow Serving it is easy to deploy different new models without any change in the server architecture and APIs. Although this type of serving is for TensorFlow models, it can be used for serving the other type of models.
# ##### Features:
# ###### Tensor flow model is used to test the empirical models, It can be used to serve different models at the same time, Tensor flow Exposes both HTTP and gRPC, Without changing the code we can deploy the new modelinference end points, It supports both tensor flow and non tensor flow based models, Tensor flow is efficient and has low latency.
# ![1.png](attachment:1.png)
#
# ##### Torchserve: TorchServe is a compatible tool for serving PyTorch models. TorchServe is an open-source framework for deploying PyTorch models at scale without having to write custom code. TorchServe can serve the models with low latency, so we can deploy our models for high-performance inference.
# ##### Features: It is used to deploy large number of models, Metrics for monitoring, RESTful endpoints for application integration, Compatible with all kind of environment such as AWS EC2, AWS EKS, Kubermetes and AWS Sagemaker having a command-line interface.
# ![2.png](attachment:2.png)
#
# ##### Gunicorn with Nginx: As a Python WSGI HTTP Server, it can be deployed with different web frameworks. It is easy to implement and warm up server resources. uWSGI is a tool which help us in making web applications and this will be done in a performant way. It is the most common tool used by many developers when they want to deploy their applications.
# ##### Nginx supports the uWSGI protocol. In this way the WSGI applications which are running on uWSGI can communicate with Nginx in the best way. It is very simple and easy to configure deployments. Finally, the combination of Gunicorn and Nginx is one of the best choice for deploying the models.
# ![3.png](attachment:3.png)
#
# ##### Cortex: Cortex is used to deploy all types of models as it is a multi frame work and open source platform for deploying ML models.
# ##### Features: Scaling the APIs automatically to balance the workloads, It can run inference on all of the amazon web service instance types Passing several models in just one API, Updating the APIs which are deployed, without any interruption, Monitoring the performance of API and also the results.
# ![4.png](attachment:4.png)
#
# ##### DeepDetect: As a deep learning API and server which is written in C++11, DeepDetect is one of the Web Platform used for managing machine learning models and training.The main aim of DeepDetect is to make deep learning simple to work with. It is supporting ML libraries including Tensorflow, XGBoost, Dlib and so forth.
# ##### Features: Deepdetect has more than 20 pre-trained models, so it can train the model very fast, It is one of the fast server because it is written in C++11, It is useful for image processing, sentiment analysis, object detection, OCR, Audio and video processing, Text classification for and time-series, Web user interface for training and managing machine learning models.
# ![5.png](attachment:5.png)
#
# ##### ForestFlow: ForestFlow can be used as a scalable cloud-native machine learning model server.It is also used to deploy and manage machine learning models.
# ##### Features: Forest flow can deploy the model in Shadow mode, It can run as a instance to manage and balance workload, With a simple configuration it can deploy native Kubernetes integration on Kubernetes clusters,  Automatically hydrates models and resources which are not in use and then re-hydrates them again into memory, Multi tenancy (a single instance of the software can serves multiple customers).
# ![6.png](attachment:6.png)
#
# ##### KFServing: By providing a Kubernetes CRD for serving ML models on frameworks, KFServing is compatible with machine learning frameworks such as TensorFlow, sklearn, PyTorch, XGBoost and so forth in order to address the machine learning model servings.
# #####  Features: Customizable Inference Service to add configurations for CPU, GPU, TPU and memory, It is used for managing the traffic, Used for managing the revision Request/Response logging Scalable Multi Model Serving.
# ![8.png](attachment:8.png)
#
# ##### BentoML: As an open-source platform with a framework, Seldon will help us to deploy our ML models much faster on Kubernetes.It can be easily operated with any public cloud provider.
# ##### Features: Easy to containerize MLmodels using our-packed interface servers or language wrappers, Metadata provenance to ensure each model can be tracked back to its respective training system, data and metrics, With Prometheus and Grafana we can perform advanced customizable metrics, It can be integrated with Elasticsearch for auditability through input output request.
# ![9.png](attachment:9.png)

# %% [markdown]
# #### Choosing the model for serving our project:
# ##### If we want to deploy our project, we will choose to make a flask application and using Gunicorn and Nginx for deploying.
#
# ##### Choosing Gunicorn: We will build a web application with Flask microframework. Flask is a Python-based web framework that is easy to use. Afterthat, we are going to deploy a Flask app to App Platform using gunicorn. By using gunicorn, we will be able to serve the flask application on more than one thread. As a WSGI web application server, Gunicorn has many functionalities. Supporting different frameworks, making Gunicorn simple to use drop-in replacement for all of development servers that are used during development.
#
# ###### Choosing Nginx: Static files like css, image and so forth can be served together with response by lots of framworks and web application servers such as Gunicorn. However, it is better to serve these files with a server such as Nginx. This will balance the workload for the application server and gives us a better performance. As the application grows, we might want to optimize and also distribute it through the servers in order to manage more requests. Therefore, using a reverse-proxy in front of the application server will helps us with this issue.
#
# ![10.1.png](attachment:10.1.png)
#
# ![10.2.png](attachment:10.2.png)

# %% [markdown]
# #### The dataset is Consumer Complaints on Financial products , and we'll look at how to group customer complaints text into these categories: Consumer loans, mortgages, credit cards, credit reporting, student loans, bank accounts or services, payday loans, money transfers, other banking services, prepaid cards and debt collection.

# %% [markdown]
# #### We have performed initial analysis using text data performed text pre-processing steps such as Text Standardization,Removing Stopwords,Lemmatization.
# #### Utilized SVM ,Logistic Regression, and CNN models to classify text data into 11 categories.

# %% [markdown]
# # Model Selection
#
# ## Support Vector Machine(SVM)
#
# #### We have used Support Vector Machine(SVM) supervised machine learning algorithms which are used both for classification and regression.
# #### SVMs have their unique way of implementation as compared to other machine learning algorithms. Lately, they are extremely popular because of their ability to handle multiple continuous and categorical variables.
#
# #### Advantages
# #### SVM Classifiers offer good accuracy and perform faster prediction compared to Naïve Bayes algorithm.
# #### They also use less memory because they use a subset of training points in the decision phase.
# #### SVM works well with a clear margin of separation and with high dimensional space.
#
# ### Summary
#
#
# #### We have trained dataset on Logistic Regression, Support Vector Machine(SVM), and CNN.
# #### The following are the results of using SVM and Logistic Regression. SVM optimises the margin  between the nearest support vectors, while logistic regression aims to increase the probability of the posterior class.
# #### SVM is deterministic (but we can use Platts model for probability score) while LR is probabilistic.
# #### For the kernel space, SVM is faster.
#
# #### In the end, we have achieved an accuracy of around 85% for Logistic Regression & Support Vector Machine(SVM) and around 86% for CNN.
#
# #### we get good results with CNN.
#
# #### From the learning curves in CNN it is clear the model needs to be tuned for overfitting by selecting hyperparameters such as no of epochs via early stopping and dropout for regularization.

# %%
import numpy as np
import pandas as pd

#to ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#path_file = "consumer_complaints.csv"
df = pd.read_csv("consumer_complaints.csv", engine='python')

# %%
#printing first 5 rows in the dataset
df.head()
# Out:
#   date_received           product               sub_product  \
# 0    08/30/2013          Mortgage            Other mortgage
# 1    08/30/2013          Mortgage            Other mortgage
# 2    08/30/2013  Credit reporting                       NaN
# 3    08/30/2013      Student loan  Non-federal student loan
# 4    08/30/2013   Debt collection               Credit card
#
#                                       issue  \
# 0  Loan modification,collection,foreclosure
# 1  Loan servicing, payments, escrow account
# 2    Incorrect information on credit report
# 3                        Repaying your loan
# 4        False statements or representation
#
#                            sub_issue consumer_complaint_narrative  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                     Account status                          NaN
# ...

# %%
#checking the types of labels
df.dtypes
# Out:
# date_received                   object
# product                         object
# sub_product                     object
# issue                           object
# sub_issue                       object
# consumer_complaint_narrative    object
# company_public_response         object
# company                         object
# state                           object
# zipcode                         object
# tags                            object
# consumer_consent_provided       object
# submitted_via                   object
# date_sent_to_company            object
# company_response_to_consumer    object
# timely_response                 object
# consumer_disputed?              object
# complaint_id                     int64
# dtype: object

# %%
#generating descriptive statistics of the data set

df.describe(include='all')
# Out:
#        date_received   product     sub_product  \
# count         555957    555957          397635
# unique          1608        11              46
# top       08/27/2015  Mortgage  Other mortgage
# freq             963    186475           74319
# mean             NaN       NaN             NaN
# std              NaN       NaN             NaN
# min              NaN       NaN             NaN
# 25%              NaN       NaN             NaN
# 50%              NaN       NaN             NaN
# 75%              NaN       NaN             NaN
# max              NaN       NaN             NaN
#
#                                            issue       sub_issue  \
# count                                     555957          212622
# unique                                        95              68
# top     Loan modification,collection,foreclosure  Account status
# freq                                       97191           26798
# mean                                         NaN             NaN
# ...

# %% [markdown]
# ### Percentage of missing values in each column in the dataset

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# date_received                    0.000000
# product                          0.000000
# sub_product                     28.477382
# issue                            0.000000
# sub_issue                       61.755675
# consumer_complaint_narrative    87.983603
# company_public_response         84.688744
# company                          0.000000
# state                            0.879025
# zipcode                          0.810314
# tags                            85.977513
# consumer_consent_provided       77.793606
# submitted_via                    0.000000
# date_sent_to_company             0.000000
# company_response_to_consumer     0.000000
# timely_response                  0.000000
# consumer_disputed?               0.000000
# complaint_id                     0.000000
# dtype: float64

# %%
#created new variable df1 for col with least null values

df1 = df[['complaint_id','date_received','product','issue','company','state','submitted_via','company_response_to_consumer','timely_response','consumer_disputed?','consumer_complaint_narrative']]

# %%
df1 = df1[pd.notnull(df1['consumer_complaint_narrative'])]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# #### We'll check the disribution of complaints by product category to understand which product received maximum complaints and other products which rarely receive complaints.

# %%
#used seaborn and matplot to generta plot

import seaborn as sns
import matplotlib.pyplot as plt

fig,ax = plt.subplots(figsize=(18,6))
sns.countplot(x='product',data=df1)

# %% [markdown]
# #### From this plot we can see Debt Collection, Mortgage, and credit reporting received maximum number of complaints.

# %% [markdown]
# #### We’ll now analyze the contingency table in form of plot to understand which product has more customer disputes on their complaints after resolving the issues.

# %%
#plotted graph to check the customer disputed

pd.crosstab(df1['product'],df1['consumer_disputed?']).plot(kind='bar')

# %% [markdown]
# #### From above graph we can see that there is not much of difference in proportion of disputes raised by complaint for each product category.
# #### So checking for other plots to recognize patterns within data.

# %% [markdown]
# ####

# %% [markdown]
# ##### Converting string Date time into Python Date time object

# %%
df1['date_received'] = pd.to_datetime(df1['date_received'])

# %%
df1.date_received.min(),df1.date_received.max()
# Out:
# (Timestamp('2015-03-19 00:00:00'), Timestamp('2016-04-20 00:00:00'))

# %%
df1['month'] = df1['date_received'].dt.month

# %%
sns.countplot(x='month',data=df1)

# %% [markdown]
# #### Above plot shows no.of complaints per month.

# %%
sns.countplot(x='timely_response',data=df1)

# %% [markdown]
# #### Above plot shows whether the reponse is given in time or not

# %% [markdown]
# ## Text Data Preprocessing

# %% [markdown]
# #### Step 1: Converting Text data to Lowercase.

# %%
df1['consumer_complaint_narrative'] =df1['consumer_complaint_narrative'].apply(lambda x: ' '.join([i.lower() for i in x.split()]))

# %%
#sample to check o/p
df1['consumer_complaint_narrative'].sample(2)
# Out:
# 262851    credit card companies are deleting historical ...
# 271241    i filed a dispute for an unknown medical accou...
# Name: consumer_complaint_narrative, dtype: object

# %% [markdown]
# #### Step 2: Removing Punctuations.

# %%
df1['consumer_complaint_narrative'] =df1['consumer_complaint_narrative'].str.replace(r'[^\w\s]',"")

# %%
#sample to check o/p
df1['consumer_complaint_narrative'].sample(2)
# Out:
# 516227    i was not working when receiving a judgement f...
# 249456    my home equity line of credit matured a little...
# Name: consumer_complaint_narrative, dtype: object

# %% [markdown]
# #### Step 3: Text Standardization using dictionaries.

# %%
#we used three normalizazion dictionaries from these links :
#http://www.hlt.utdallas.edu/~yangl/data/Text_Norm_Data_Release_Fei_Liu/
#http://people.eng.unimelb.edu.au/tbaldwin/etc/emnlp2012-lexnorm.tgz
#http://luululu.com/tweet/typo-corpus-r1.txt


dico = {}
dico1 = open('doc1.txt', 'rb')
for word in dico1:
    word = word.decode('utf8')
    word = word.split()
    dico[word[1]] = word[3]
dico1.close()
dico2 = open('doc2.txt', 'rb')
for word in dico2:
    word = word.decode('utf8')
    word = word.split()
    dico[word[0]] = word[1]
dico2.close()
dico3 = open('doc3.txt', 'rb')
for word in dico3:
    word = word.decode('utf8')
    word = word.split()
    dico[word[0]] = word[1]
dico3.close()

# %%
def txt_std(words):
    list_words = words.split()
    for i in range(len(list_words)):
        if list_words[i] in dico.keys():
            list_words[i] = dico[list_words[i]]
    return ' '.join(list_words)

# %%
#applying txt_std function

df1['consumer_complaint_narrative'] = df1['consumer_complaint_narrative'].apply(txt_std)

# %%
#sample to check o/p
df1.consumer_complaint_narrative.head(1)
# Out:
# 190126    xxxx has claimed i owe them 2700 for xxxx year...
# Name: consumer_complaint_narrative, dtype: object

# %%
#replacing specified phrase

df1['consumer_complaint_narrative'] = df1['consumer_complaint_narrative'].str.replace(r"xx+\s","")

# %%
#sample to check o/p
df1['consumer_complaint_narrative'].head(1)
# Out:
# 190126    has claimed i owe them 2700 for years despite ...
# Name: consumer_complaint_narrative, dtype: object

# %% [markdown]
# #### Step 4: Removing Stopwords.

# %%
#removing stop words using stopwords.words('english') which returns a list of lowercase stop words

from nltk.corpus import stopwords
stop = stopwords.words('english')
df1['consumer_complaint_narrative'] =df1['consumer_complaint_narrative'].apply(lambda x: ' '.join([i for i in x.split() if i not in stop]))

# %%
#sample to check o/p
df1['consumer_complaint_narrative'].head(1)
# Out:
# 190126    claimed owe 2700 years despite proof payment s...
# Name: consumer_complaint_narrative, dtype: object

# %% [markdown]
# #### Step 5: Lemmatizing.

# %%
from textblob import Word
df1['consumer_complaint_narrative'] =df1['consumer_complaint_narrative'].apply(lambda x:' '.join([Word(i).lemmatize() for i in x.split()]))

# %%
df1.consumer_complaint_narrative.head(1)
# Out:
# 190126    claimed owe 2700 year despite proof payment se...
# Name: consumer_complaint_narrative, dtype: object

# %% [markdown]
# # Train/Test split
# ### We have split data in 75:25 Percentage.

# %%
df1['label'] = df1['product'].map({'Debt collection': 0, 'Mortgage': 1,'Credit reporting': 2, 'Credit card': 3,
                                'Bank account or service': 4,'Consumer Loan': 5, 'Student loan': 6,'Prepaid card': 7,
                                 'Payday loan': 8,'Money transfers':9,'Other financial service': 10})

X = df1['consumer_complaint_narrative']
y = df1['label']

# %%
from sklearn.model_selection import train_test_split

train_x, valid_x, train_y, valid_y = train_test_split(X, y, stratify=y, 
                                                    test_size=0.25)

# %% [markdown]
# ## SVM

# %%
import numpy as np

train_y = np.array(train_y)
valid_y = np.array(valid_y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer =  TfidfVectorizer(analyzer='word', max_features=5000, stop_words='english')
vectorizer.fit(df1['consumer_complaint_narrative'])

# convert the texts into a matrix

train_x_tfidf = vectorizer.transform(train_x)
valid_x_tfidf  = vectorizer.transform(valid_x)

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV

# Creat hyperparameters:
# It should be as a dictionary with hyperparameter as a key
# Using the range of 0.001 to 100 

SV_parameters = {'C':[0.001,0.01,0.1,1,10,100]}

# Creat Grid Search:
# For the estimator we choose the SVM as our model
# Using None for cv (cv=None), to use the default 5-fold cross validation
# Selecting number of jobs as -1 (n_jobs=-1). This will use all the cores available on the machine.
GS_SVM = GridSearchCV(estimator=LinearSVC(),param_grid=SV_parameters,cv=None,n_jobs=-1)

# Fit the gridSearch on training data.
GS_SVM.fit(train_x_tfidf,train_y)

# Print the Best Hyperparameter
print("Best Hyperparameter: ",GS_SVM.best_params_['C'])
# Out:
# Best Hyperparameter:  0.1

# %%
# SVM Classifier
from sklearn.svm import LinearSVC
SVM = LinearSVC(C=0.1, class_weight=None, dual=True, fit_intercept=True,intercept_scaling=1, loss='squared_hinge',
                max_iter=1000,multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,verbose=0)
SVM.fit(train_x_tfidf,train_y)
# Out:
# LinearSVC(C=0.1)

# %%
#pipeline


from sklearn.pipeline import Pipeline
pipeline = Pipeline(steps= [('TFIDF', TfidfVectorizer(analyzer='word', max_features=5000, ngram_range=(1,1))),
                            ('model', LinearSVC(C=0.1,max_iter=1000,class_weight=None,loss='squared_hinge',
                                                tol=0.0001,verbose=0,multi_class='ovr'))])

# %%
pipeline.fit(train_x, train_y)
# Out:
# Pipeline(steps=[('TFIDF', TfidfVectorizer(max_features=5000)),
#                 ('model', LinearSVC(C=0.1))])

# %%
data = ["I need money to build my house"]
# Vectorize the text
# Predict the tex
predict = pipeline.predict(data)
predict
# Out:
# array([1], dtype=int64)

# %%
labels = ['Debt collection', 'Mortgage','Credit reporting', 'Credit card','Bank account or service','Consumer Loan',
          'Student loan','Prepaid card','Payday loan','Money transfers','Other financial service']
labels[int(predict)]
# Out:
# 'Mortgage'

# %%
#model saving
import joblib

joblib.dump(pipeline, filename="consumercomplaint.joblib")
# Out:
# ['consumercomplaint.joblib']

# %%
import joblib

pipeline = joblib.load('consumercomplaint.joblib')

# %%
data = ['I lost my money from account']
predict_new = pipeline.predict(data)

print(predict_new)
# Out:
# [4]

# %%
labels = ['Debt collection', 'Mortgage','Credit reporting', 'Credit card','Bank account or service','Consumer Loan',
          'Student loan','Prepaid card','Payday loan','Money transfers','Other financial service']
print(labels[int(predict_new)])
# Out:
# Bank account or service

# %% [markdown]
# ## LOCAL DEPLOYMENT

# %%
#app.py

from flask import Flask,render_template,url_for,request
import pandas as pd 
from sklearn.svm import LinearSVC
import joblib


app = Flask(__name__)

@app.route('/')
def home():
    return render_template('home.html')

@app.route('/predict',methods=['POST'])
def predict():
    pipeline = joblib.load('consumercomplaint.joblib')
    labels = ['Debt collection', 'Mortgage','Credit reporting', 'Credit card','Bank account or service','Consumer Loan','Student loan','Prepaid card','Payday loan','Money transfers','Other financial service']
    my_file = open("complaintlog.csv", "a")
    if request.method == 'POST':
        message = request.form['message']
        msg = request.form['name']
        data = [message]
        name = [msg]
        prediction = pipeline.predict(data)
        my_file.write("\n{},".format((name)))
        my_file.write("{},".format(str(message)))
        my_file.write("{},".format(str(labels[int(prediction)])))
        my_file.close()

        return render_template('predict.html',prediction = prediction)

if __name__ == '__main__':  
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
